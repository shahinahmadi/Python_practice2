# %% [markdown]
# # Taking multiple .csv files concatinating them and analyzing them

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
df1 = pd.read_csv("./Data/example1.CSV")
files=[file for file in os.listdir("Data")]
all_data=pd.DataFrame()
for file in files:
    df2=pd.read_csv("./Data/"+file, index_col = 0)
    all_data=pd.concat([all_data,df2])
    all_data.to_csv("all_data.csv", index=False)
plt.plot(df1.Wave,df1.Transmittance)
plt.xlabel('Wavelength(nm)')
plt.ylabel('Transmittance(%)')
plt.ylim(0,200)
plt.xlim(180,1300)
plt.legend(['Single measurement'])
plt.show()
all_data=pd.read_csv("all_data.csv")
all_data.head()
# Out:
#    Transmittance  Std.Dev.
# 0       0.100011  0.016147
# 1       0.060121  0.008177
# 2       0.090859  0.017454
# 3       0.075132  0.009659
# 4       0.100395  0.012889

# %% [markdown]
# # Ploting different data in one graph

# %%
from pathlib import Path
path = Path("./Data")
print(path.parent)
DF1 = pd.read_csv("./Data/example1.CSV")
DF2=pd.read_csv("./Data/example2.CSV")
DF3=pd.read_csv("./Data/example3.CSV")
df3.head()
plt.plot(DF1.Wave,DF1.Transmittance, color='g', linewidth=1)
plt.plot(DF2.Wave,DF2.Transmittance, color='r', linewidth=1)
plt.plot(DF3.Wave,DF3.Transmittance, color='b', linewidth=1)
plt.xlabel('Wavelength(nm)')
plt.ylabel('Transmittance(%)')
plt.legend(['first','second','third'])
plt.ylim(0,200)
plt.xlim(180,1300)
plt.show()
# Out:
# .

# %% [markdown]
# # Taking average over data and putting error bars on that

# %%
#sample.Wave
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-c6adaec02e3b> in <module>
# ----> 1 plt.plot(example1.Wave,(example1.Transmittance+example2.Transmittance+example3.Transmittance)/3, color='g', linewidth=1)
#       2 plt.xlabel("Wavelength(nm)")
#       3 plt.ylabel("Transmittance(%)")
#       4
#
# NameError: name 'example1' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot(sample1.Wave,sample1.Transmittance, color='g', linewidth=1)
plt.plot(sample2.Wave,sample2.Transmittance, color='r', linewidth=1)
plt.plot(sample3.Wave,sample3.Transmittance, color='b', linewidth=1)
plt.xlabel('Wavelength(nm)')
plt.ylabel('Transmittance(%)')
plt.legend(['first','second','third'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a14a4da378a0> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(sample1.Wave,sample1.Transmittance, color='g', linewidth=1)
#       3 plt.plot(sample2.Wave,sample2.Transmittance, color='r', linewidth=1)
#       4 plt.plot(sample3.Wave,sample3.Transmittance, color='b', linewidth=1)
#       5 plt.xlabel('Wavelength(nm)')
#
# NameError: name 'sample1' is not defined

# %%
plt.plot(sample1.Wave,(sample1.Transmittance+sample2.Transmittance+sample3.Transmittance)/3, color='g', linewidth=1)
plt.xlabel("Wavelength(nm)")
plt.ylabel("Transmittance(%)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3c139892a141> in <module>
# ----> 1 plt.plot(sample1.Wave,(sample1.Transmittance+sample2.Transmittance+sample3.Transmittance)/3, color='g', linewidth=1)
#       2 plt.xlabel("Wavelength(nm)")
#       3 plt.ylabel("Transmittance(%)")
#
# NameError: name 'sample1' is not defined
